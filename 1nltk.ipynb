# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import brown
#brown.categories()
brown.words(categories='adventure')[:50]
# Out:
# ['Dan',
#  'Morgan',
#  'told',
#  'himself',
#  'he',
#  'would',
#  'forget',
#  'Ann',
#  'Turner',
#  '.',
#  'He',
#  'was',
#  'well',
#  'rid',
#  'of',
#  'her',
#  '.',
#  'He',
#  'certainly',
#  "didn't",
#  'want',
#  'a',
#  'wife',
#  'who',
#  'was',
#  'fickle',
#  'as',
#  'Ann',
#  '.',
#  'If',
#  'he',
#  'had',
#  'married',
#  'her',
#  ',',
#  "he'd",
#  'have',
#  'been',
#  'asking',
#  'for',
#  'trouble',
#  '.',
#  'But',
#  'all',
#  'of',
#  'this',
#  'was',
#  'rationalization',
#  '.',
#  'Sometimes']

# %%
from nltk.corpus import inaugural

#inaugural.fileids()
inaugural.words(fileids='2017-Trump.txt')[:50]
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
from nltk.corpus import webtext
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
text1="What is Lorem Ipsum?Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.Why do we use it?It is a long established fact that a reader will be distracted by the readable content of a page when looking at its layout. The point of using Lorem Ipsum is that it has a more-or-less normal distribution of letters, as opposed to using 'Content here, content here', making it look like readable English. Many desktop publishing packages and web page editors now use Lorem Ipsum as their default model text, and a search for 'lorem ipsum' will uncover many web sites still in their infancy. Various versions have evolved over the years, sometimes by accident, sometimes on purpose (injected humour and the like)."
fd=nltk.FreqDist(text1.split())
fd
# Out:
# FreqDist({'the': 9, 'of': 7, 'a': 7, 'Lorem': 6, 'and': 6, 'Ipsum': 5, 'is': 4, 'has': 3, 'it': 3, 'dummy': 2, ...})

# %%
from nltk.probability import ConditionalFreqDist
cfd = ConditionalFreqDist((len(word),word)for word in text1.split())
cfd[10]
# Out:
# FreqDist({'publishing': 2, "industry's": 1, 'centuries,': 1, 'electronic': 1, 'unchanged.': 1, 'containing': 1, 'distracted': 1})

# %%
from nltk.probability import ConditionalFreqDist
cfd = ConditionalFreqDist((len(word),word)for word in text1.split())
cfd[12]
# Out:
# FreqDist({'typesetting,': 1, 'more-or-less': 1, 'distribution': 1})

# %%
from nltk.corpus import movie_reviews
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
from nltk.corpus import movie_reviews
movie_reviews.categories()

movie_reviews.words(categories='neg')[:10]
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party']

# %%
import random
from nltk.corpus import movie_reviews
doc=movie_reviews.fileids()
random.shuffle(doc)
print(doc[1])
#for i in doc:
 #   print(i)

#print(len(movie_reviews.fileids(categories='neg')))
# Out:
# neg/cv705_11973.txt

# %%
movie_reviews.words(fileids='neg/cv000_29416.txt')
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %%
from nltk.corpus import movie_reviews
movie_reviews.fileids()
# Out:
# ['neg/cv195_16146.txt',
#  'neg/cv705_11973.txt',
#  'pos/cv146_18458.txt',
#  'pos/cv272_18974.txt',
#  'neg/cv126_28821.txt',
#  'pos/cv337_29181.txt',
#  'pos/cv457_18453.txt',
#  'neg/cv383_14662.txt',
#  'pos/cv680_10160.txt',
#  'neg/cv363_29273.txt',
#  'neg/cv471_18405.txt',
#  'neg/cv956_12547.txt',
#  'pos/cv404_20315.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv699_7773.txt',
#  'pos/cv775_16237.txt',
#  'pos/cv920_29622.txt',
#  'pos/cv211_9953.txt',
#  'pos/cv170_3006.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv143_21158.txt',
#  'pos/cv473_7367.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv531_26838.txt',
#  'pos/cv993_29737.txt',
#  'pos/cv819_9364.txt',
#  'pos/cv530_16212.txt',
#  'neg/cv243_22164.txt',
#  'pos/cv863_7424.txt',
#  'neg/cv276_17126.txt',
#  'neg/cv424_9268.txt',
#  'pos/cv562_10359.txt',
#  'neg/cv443_22367.txt',
#  'pos/cv702_11500.txt',
#  'neg/cv493_14135.txt',
#  'neg/cv148_18084.txt',
#  'neg/cv373_21872.txt',
#  'neg/cv669_24318.txt',
# ...

# %%
from nltk.corpus import movie_reviews
movie_reviews.words(fileids='pos/cv457_18453.txt')[:100]
# Out:
# ['warning',
#  ':',
#  'if',
#  'you',
#  'actually',
#  'wish',
#  'to',
#  'see',
#  'the',
#  'film',
#  ',',
#  'stop',
#  'reading',
#  'this',
#  'and',
#  'see',
#  'it',
#  '.',
#  'while',
#  'i',
#  'don',
#  "'",
#  't',
#  'blow',
#  'any',
#  'plot',
#  'details',
#  ',',
#  'the',
#  'more',
#  'you',
#  'know',
#  'about',
#  'a',
#  'movie',
#  ',',
#  'the',
#  'more',
#  'disappointing',
#  'and',
#  'built',
#  'up',
#  'it',
#  'becomes',
#  '(',
#  'waiting',
#  'a',
#  'month',
#  'to',
#  'see',
#  'titanic',
#  'did',
#  'the',
#  'same',
#  'thing',
#  ')',
#  '.',
#  'but',
#  ',',
#  'in',
#  'a',
#  'nutshell',
#  ',',
#  'it',
#  "'",
#  's',
#  'a',
#  'good',
#  'film',
#  '.',
#  'star',
#  'wars',
#  'episode',
#  'i',
#  ':',
#  'the',
#  'phantom',
#  'menace',
#  'reviewed',
#  'by',
#  'vince',
#  'yim',
#  'never',
#  'having',
#  'been',
#  'the',
#  'biggest',
#  'star',
#  'wars',
#  'fanatic',
#  'in',
#  'the',
#  'world',
#  '(',
#  'i',
# ...
