# %%
import nltk
#TASK 1:
text1='''The first and most important principle to be observed in constructing a paragraph is that of UNITY.Just as each sentence deals with one thought, each paragraph must deal with one topic or idea – and with no more than one. 
In writing an essay, for example, every head, and every sub-head, should have its own paragraph to itself. And every sentence in the paragraph must be closely connected with the main topic of the paragraph.
The paragraph and every part of it must be the expression of one theme or topic.

Note: A good practice is to read a chapter in a book, and give a short heading or title to each paragraph, which will express in a word or brief phrase the subject of the paragraph.
  '''
for text in text1:
    sentences=nltk.sent_tokenize(text1)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# [('The', 'DT'), ('first', 'JJ'), ('and', 'CC'), ('most', 'RBS'), ('important', 'JJ'), ('principle', 'NN'), ('to', 'TO'), ('be', 'VB'), ('observed', 'VBN'), ('in', 'IN'), ('constructing', 'VBG'), ('a', 'DT'), ('paragraph', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('of', 'IN'), ('UNITY.Just', 'NNP'), ('as', 'IN'), ('each', 'DT'), ('sentence', 'NN'), ('deals', 'NNS'), ('with', 'IN'), ('one', 'CD'), ('thought', 'NN'), (',', ','), ('each', 'DT'), ('paragraph', 'NN'), ('must', 'MD'), ('deal', 'VB'), ('with', 'IN'), ('one', 'CD'), ('topic', 'NN'), ('or', 'CC'), ('idea', 'NN'), ('–', 'NNS'), ('and', 'CC'), ('with', 'IN'), ('no', 'DT'), ('more', 'JJR'), ('than', 'IN'), ('one', 'CD'), ('.', '.')]
# ...

# %%
#TASK 2:
from nltk.tokenize import TweetTokenizer
text='The first and most important principle to be observed in constructing a paragraph is that of UNITY.Just as each sentence deals with one thought, each paragraph must deal with one topic or idea – and with no more than one.'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The',
#  'first',
#  'and',
#  'most',
#  'important',
#  'principle',
#  'to',
#  'be',
#  'observed',
#  'in',
#  'constructing',
#  'a',
#  'paragraph',
#  'is',
#  'that',
#  'of',
#  'UNITY.Just',
#  'as',
#  'each',
#  'sentence',
#  'deals',
#  'with',
#  'one',
#  'thought',
#  ',',
#  'each',
#  'paragraph',
#  'must',
#  'deal',
#  'with',
#  'one',
#  'topic',
#  'or',
#  'idea',
#  '–',
#  'and',
#  'with',
#  'no',
#  'more',
#  'than',
#  'one',
#  '.']

# %%
#Task 3:
from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
type(raw)
len(raw)
raw[:75]
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
#html=>ascii=>text=>vocab
# Out:
# list

# %%
#task4:
import nltk
f=open('tweets1.txt','r')
text=f.read()
text1=text.split()
text2=nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# n The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast ne
# so going to enjoy this shower. Feels good to have worked on a trail three time
# ose not my friend. it was not a very good day so I have a lot to do tomorrow..
# Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "
# utiful day so Im thinking to spend a good part of it outdoors.first stop at St
# g and ignoring my reaction to a very good friend getting fired. it's like a bi
# d HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Bein
#  I bet I can throw farther than her. Good luck with that dude. Sure it will al
#  Choppers. first day of eid .. feels good Looking to buy a game called Shut th
# g. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to ste
# tching the CNBC video of David Lear. Good job Sean! and now... off to Belize!
# ...
